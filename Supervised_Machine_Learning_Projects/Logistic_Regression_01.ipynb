# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement-dataset.csv")

# %%
df = df.iloc[:,1:]

# %%
avg1 = df["iq"]

# %%
np.max(avg1)
# Out:
# 233.0

# %%
stname = df[df['iq'] == 233.0]

# %%
stname
# Out:
#     cgpa     iq  placement
# 50   3.5  233.0          0

# %%
x1 = df["cgpa"]
y1 = df["iq"] 

plt.scatter(x1, y1, c=df['placement'])
plt.xlabel("cgpa of students")
plt.ylabel("iq of that's students")
plt.title("placement graph")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 83   7.5  130.0
# 46   5.3  114.0
# 1    5.9  106.0
# 98   6.3  103.0
# 58   8.0   79.0
# ..   ...    ...
# 82   6.5   37.0
# 22   4.9  120.0
# 48   6.6  138.0
# 4    5.8  142.0
# 41   5.4  114.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 83    1
# 46    0
# 1     0
# 98    1
# 58    1
#      ..
# 82    1
# 22    0
# 48    1
# 4     0
# 41    0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.32402363,  0.17977793],
#        [-0.65153537, -0.21246482],
#        [-0.11274655, -0.40858619],
#        [ 0.246446  , -0.48213171],
#        [ 1.77301431, -1.07049583],
#        [ 0.78523481,  0.40041447],
#        [ 0.246446  ,  0.13074758],
#        [ 1.86281245,  1.06232411],
#        [ 0.42604227,  0.17977793],
#        [ 0.42604227, -0.80082894],
#        [ 0.06684972,  0.22880827],
#        [-1.10052605,  0.98877859],
#        [ 0.78523481,  0.3758993 ],
#        [-1.01072791,  0.69459653],
#        [ 2.22200499, -0.06537379],
#        [-1.90870927, -0.33504068],
#        [-0.7413335 ,  2.48420406],
#        [-1.54951673,  1.89583994],
#        [-0.02294841, -1.90401167],
#        [-0.29234282,  0.22880827],
#        [ 0.06684972, -1.41370823],
#        [-0.02294841, -1.38919306],
#        [ 0.78523481, -0.65373791],
#        [ 0.87503295, -0.26149516],
#        [ 0.87503295,  1.28296065],
#        [ 0.42604227,  0.91523308],
#        [-1.01072791,  0.27783861],
#        [ 0.96483109, -1.83046615],
#        [ 0.5158404 , -0.06537379],
#        [ 0.33624413,  0.44944481],
#        [ 0.69543668, -0.26149516],
#        [ 0.246446  ,  0.10623241],
#        [-1.10052605,  0.44944481],
#        [-1.28012232,  0.57202067],
#        [ 0.06684972,  0.81717239],
#        [-0.02294841, -0.50664688],
#        [-0.65153537, -0.04085862],
#        [ 0.33624413, -0.16343448],
#        [ 1.14442736, -0.89888963],
#        [ 0.69543668, -0.80082894],
#        [ 0.60563854,  0.76814205],
#        [-0.56173723,  0.40041447],
#        [ 0.87503295, -1.43822341],
#        [ 1.59341804, -0.21246482],
#        [-0.29234282,  1.13586962],
#        [ 0.15664786, -0.23697999],
#        [ 0.06684972, -1.02146549],
#        [ 1.23422549,  0.22880827],
#        [ 0.69543668,  0.44944481],
#        [-1.01072791, -1.51176892],
#        [-2.26790182,  2.70484061],
#        [ 0.87503295,  1.87132477],
#        [-0.7413335 , -0.31052551],
#        [-0.7413335 , -0.80082894],
#        [-1.10052605,  1.13586962],
#        [-2.44749809,  1.47908203],
#        [-1.19032418, -0.04085862],
#        [ 0.87503295,  0.40041447],
#        [ 0.96483109,  0.69459653],
#        [-1.81891114, -1.16855652],
#        [ 1.41382177,  0.13074758],
#        [-0.29234282,  0.42492964],
#        [-1.45971859,  0.64556619],
#        [ 1.14442736, -1.78143581],
#        [-1.19032418, -0.87437446],
#        [-0.92092977, -1.46273858],
#        [ 0.69543668,  0.00817172],
#        [-0.02294841,  0.0326869 ],
#        [-0.02294841,  0.64556619],
#        [-0.20254468,  1.06232411],
#        [-1.19032418, -1.73240547],
#        [ 0.60563854,  1.45456685],
#        [-0.83113164,  1.30747582],
#        [ 1.32402363,  0.86620273],
#        [-1.45971859, -1.97755718],
#        [-0.92092977, -0.77631377],
#        [ 2.04240872,  1.11135445],
#        [-0.29234282,  0.49847516],
#        [-0.7413335 ,  0.22880827],
#        [ 0.06684972, -0.48213171],
#        [-0.83113164, -1.38919306],
#        [ 1.41382177, -0.82534411],
#        [ 1.32402363, -1.51176892],
#        [-0.56173723,  0.30235378],
#        [-0.7413335 ,  0.93974825],
#        [ 0.42604227, -2.10013304],
#        [-1.01072791, -0.06537379],
#        [ 0.5158404 ,  0.3758993 ],
#        [-0.20254468,  0.47395999],
#        [-0.56173723, -0.21246482]])

# %%
x_test = scaler.transform(X_test)

# %%
x_test
# Out:
# array([[-1.10052605, -0.26149516],
#        [-0.92092977, -0.11440413],
#        [ 1.14442736, -0.16343448],
#        [-1.81891114, -0.55567722],
#        [ 1.86281245,  0.64556619],
#        [ 1.14442736,  0.35138413],
#        [-1.01072791,  0.79265722],
#        [-0.56173723, -0.38407102],
#        [-1.01072791,  1.79777926],
#        [-0.83113164,  0.13074758]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
 clf = LogisticRegression()

# %%
# model training
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 59    0
# 67    0
# 72    1
# 18    0
# 37    1
# 61    1
# 76    0
# 81    0
# 80    0
# 86    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
